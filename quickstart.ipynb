# %% [markdown]
# # Clone repository

# %%
# !git clone https://github.com/wh1tePigeon/AutoDub
# %cd AutoDub

# %% [markdown]
# # Install requirements

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # Download checkpoints

# %%
# %cd AutoDub
#run if env disconnected

# %%
# !python download_checkpoints.py

# %% [markdown]
# # Run dub

# %%
# !python dub_baseline.py

# %% [markdown]
# If you want to test other files, upload them to AutoDub folder and change either "filepath" in source/configs/dub.yaml or FILEPATH in dub_baseline.py.
